# %% [markdown]
# ## Blackcoffer Assignment

# %% [markdown]
# **Objective of this assignment is to extract some sections (which are mentioned below) from SEC / EDGAR financial reports and perform text analysis to compute variables listed below.**

# %% [markdown]
# * Positive score
# * Negative score
# * Polarity score
# * Average Sentence Length
# * Percentage of complex words
# * Fog index
# * Complex word count
# * Word count
# * Uncertainty
# * Constraining

# %% [markdown]
# Importing the required modules.

# %%
import numpy as np
import pandas as pd
import nltk

# %% [markdown]
# Now importing cik list form assignment folder.

# %%
cik_list = pd.read_excel("Assignment/cik_list.xlsx")

display(cik_list)
# Out:
#        CIK                      CONAME   FYRMO      FDATE     FORM  \
# 0     3662            SUNBEAM CORP/FL/  199803 1998-03-06  10-K405
# 1     3662            SUNBEAM CORP/FL/  199805 1998-05-15     10-Q
# 2     3662            SUNBEAM CORP/FL/  199808 1998-08-13  NT 10-Q
# 3     3662            SUNBEAM CORP/FL/  199811 1998-11-12   10-K/A
# 4     3662            SUNBEAM CORP/FL/  199811 1998-11-16  NT 10-Q
# 5     3662            SUNBEAM CORP/FL/  199811 1998-11-25   10-Q/A
# 6     3662            SUNBEAM CORP/FL/  199812 1998-12-22     10-Q
# 7     3662            SUNBEAM CORP/FL/  199812 1998-12-22     10-Q
# 8     3662            SUNBEAM CORP/FL/  199903 1999-03-31  NT 10-K
# 9     3662            SUNBEAM CORP/FL/  199905 1999-05-11     10-K
# 10    3662            SUNBEAM CORP/FL/  199905 1999-05-17  NT 10-Q
# 11    3662            SUNBEAM CORP/FL/  199906 1999-06-11     10-Q
# 12    3662            SUNBEAM CORP/FL/  199908 1999-08-16  NT 10-Q
# ...

# %% [markdown]
# Adding https://www.sec.gov/Archives/ to every cells of column **SECFNAME** to access link to the financial report.

# %%
host_link = "https://www.sec.gov/Archives/"

cik_list['SECFNAME'] = host_link + cik_list['SECFNAME']

# %% [markdown]
# Displaying some of the values to see if the hostlink is correctly appended or not.

# %%
print(cik_list['SECFNAME'].values)
# Out:
# ['https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-000413.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-001001.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950172-98-000783.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-002145.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950172-98-001203.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-002278.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-002401.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-98-002402.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950172-99-000362.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-99-000775.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950172-99-000584.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950170-99-001005.txt'
#  'https://www.sec.gov/Archives/edgar/data/3662/0000950172-99-001074.txt'
# ...

# %% [markdown]
# Obtaining data from the links.

# %%
def parser(page):
    soup = BeautifulSoup(page, "lxml")
    
    MDA = []     #Management's Discussion and Analysis
    QQDMR = []   #Quantitative and Qualitative Disclosures about Market Risk
    RF = []      #Risk Factors
    
    """
    Finding the index table from the page to look for Management's Discussion and Analysis, Quantitative and Qualitative Disclosures about Market Risk, 
    Risk Factors if they exist.
    """
    table = soup.select('table:nth-of-type(1)')
    for tb in table:
#         if(tb.find_all(text = "Management's Discussion")):
#             print("MDA exist")
#         else:
#             print("MDA does not exist")
        print(tb)
#     print(table)
# Out:
#   File "<ipython-input-1-1bdcd856f50a>", line 18
#     print tb
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(print tb)?

# %%
import urllib
from bs4 import BeautifulSoup

for link in cik_list['SECFNAME']:
    page = urllib.request.urlopen(link)
    parser(page)
# Out:
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# MDA does not exist
# ...
